# %%
import pandas as pd
import numpy as np

# %%
dfm = pd.read_csv('open_2020_m.csv')
dff = pd.read_csv('open_2020_f.csv')

# %%
dff
# Out:
#                                name sex country_cod)        country  \
# 0    Ragnheiður Sara Sigmundsdottir   F           IS        Iceland
# 1                Annie Thorisdottir   F           IS        Iceland
# 2                     Kristin Holte   F           NO         Norway
# 3                  Tia-Clair Toomey   F           AU      Australia
# 4                      Jamie Greene   F           NZ    New Zealand
# ..                              ...  ..          ...            ...
# 495          Anna Hulda Olafsdottir   F           IS        Iceland
# 496                   Belinda Heber   F           AT        Austria
# 497                    Diana Schnee   F           US  United States
# 498                  Heather Gammel   F           US  United States
# 499                  Marina Fedenko   F           UA        Ukraine
#
#              affiliate_name  age  height  weight  countryChampion  \
# 0         Simmagym CrossFit   27  173 cm   69 kg             True
# ...

# %%
frames = [dfm, dff]
cf_data = pd.concat(frames)

# %%
cf_data
# Out:
#                           name sex country_cod)        country  \
# 0              Patrick Vellner   M           CA         Canada
# 1                Mathew Fraser   M           US  United States
# 2         Lefteris Theofanidis   M           GR         Greece
# 3    Björgvin Karl Guðmundsson   M           IS        Iceland
# 4                Jeffrey Adler   M           CA         Canada
# ..                         ...  ..          ...            ...
# 495     Anna Hulda Olafsdottir   F           IS        Iceland
# 496              Belinda Heber   F           AT        Austria
# 497               Diana Schnee   F           US  United States
# 498             Heather Gammel   F           US  United States
# 499             Marina Fedenko   F           UA        Ukraine
#
#              affiliate_name  age  height  weight  countryChampion  \
# 0          CrossFit Nanaimo   30   71 in  195 lb            False
# 1           CrossFit Mayhem   30   67 in  195 lb             True
# ...

# %%
champ_m = cf_data[(cf_data['countryChampion'] == True) & (cf_data['sex'] == 'M')]
champ_f = cf_data[(cf_data['countryChampion'] == True) & (cf_data['sex'] == 'F')]

# %%
dir(champ_f)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
champ_f.head(10)
# Out:
#                               name sex country_cod)        country  \
# 0   Ragnheiður Sara Sigmundsdottir   F           IS        Iceland
# 2                    Kristin Holte   F           NO         Norway
# 3                 Tia-Clair Toomey   F           AU      Australia
# 4                     Jamie Greene   F           NZ    New Zealand
# 5                      Kari Pearce   F           US  United States
# 6                     Emma McQuaid   F           IE        Ireland
# 7        Carol-Ann Reason-Thibault   F           CA         Canada
# 8                    Karin Freyová   F           SK       Slovakia
# 9                    Laura Horvath   F           HU        Hungary
# 12     Camilla Salomonsson Hellman   F           SE         Sweden
#
#           affiliate_name  age  height  weight  countryChampion  overallRank  \
# 0      Simmagym CrossFit   27  173 cm   69 kg             True            1
# ...

# %%
champ_m.head(10)
# Out:
#                          name sex country_cod)             country  \
# 1               Mathew Fraser   M           US       United States
# 2        Lefteris Theofanidis   M           GR              Greece
# 3   Björgvin Karl Guðmundsson   M           IS             Iceland
# 4               Jeffrey Adler   M           CA              Canada
# 6                Bayden Brown   M           AU           Australia
# 9            Roman Khrennikov   M           RU  Russian Federation
# 10                Jonne Koski   M           FI             Finland
# 25                Zack George   M           GB      United Kingdom
# 29              Willy Georges   M           FR              France
# 37        Klaus Hebo Uggerhoj   M           DK             Denmark
#
#          affiliate_name  age  height  weight  countryChampion  overallRank  \
# 1       CrossFit Mayhem   30   67 in  195 lb             True            2
# 2                   NaN   30  171 cm   81 kg             True            3
# ...
